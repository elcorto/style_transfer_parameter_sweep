# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import display
import warnings
import holoviews as hv

import vistools 

warnings.filterwarnings('ignore')
hv.extension('matplotlib')

for holomap in vistools.get_holomaps().values():
    display(holomap)
    
print("finished")
